# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bae-v3/blob/main/part4/ch11/p11_type1.ipynb)

# %% [markdown]
# ## 작업형1

# %% [markdown]
# ### 문제1

# %%
# 1-2.
EV = df['2021']
BV = df['2001']

df['CAGR'] = (EV/BV)**(1/20) -1
df['CAGR'].max()
# Out:
# 0.047102643079995676

# %%
# 1-1.
max_idx = df.iloc[:, 1:].idxmax()
df.iloc[max_idx]['Country'].value_counts()[0]

#df.iloc[:, 1:].idxmax().value_counts().iloc[0]
# Out:
# /tmp/ipykernel_2959/3460376958.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[max_idx]['Country'].value_counts()[0]
# np.int64(11)

# %%
# 풀이1-1
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bae-v3/main/part4/ch11/greenhouse_gas.csv')
df
# Out:
#            Country   2001   2002   2003   2004   2005   2006   2007   2008  \
# 0           Brazil  520.5  528.3  535.1  540.8  545.2  550.5  555.9  560.3
# 1            China  380.5  390.2  400.8  412.5  425.3  440.1  456.8  475.2
# 2              USA  490.8  492.5  494.2  496.1  498.3  500.5  502.8  505.2
# 3            India  280.3  285.7  291.2  296.9  302.8  308.9  315.2  321.7
# 4           Russia  350.5  352.8  355.2  357.6  360.1  362.7  365.4  368.2
# 5            Japan  310.2  312.5  314.8  317.2  319.6  322.1  324.6  327.2
# 6          Germany  290.5  292.3  294.1  295.9  297.8  299.7  301.6  303.6
# 7        Indonesia  245.8  250.2  254.7  259.3  264.0  268.8  273.7  278.7
# 8           Canada  265.3  267.1  268.9  270.8  272.7  274.6  276.6  278.6
# 9      South Korea  215.7  218.9  222.2  225.5  228.9  232.4  235.9  239.5
# 10            Iran  198.4  202.1  205.9  209.8  213.8  217.9  222.1  226.4
# 11    Saudi Arabia  186.2  189.5  192.9  196.4  200.0  203.7  207.5  211.4
# 12          Mexico  175.8  178.7  181.7  184.7  187.8  191.0  194.3  197.6
# 13       Australia  168.5  171.2  173.9  176.7  179.6  182.5  185.5  188.6
# 14  United Kingdom  155.3  157.6  159.9  162.3  164.7  167.2  169.7  172.3
# 15          France  142.7  144.8  146.9  149.1  151.3  153.6  155.9  158.3
# 16           Italy  138.2  140.2  142.2  144.3  146.4  148.6  150.8  153.0
# 17          Turkey  125.4  127.8  130.3  132.8  135.4  138.1  140.8  143.6
# 18          Poland  118.6  120.7  122.9  125.1  127.4  129.7  132.1  134.5
# 19           Spain  112.3  114.2  116.2  118.2  120.3  122.4  124.6  126.8
# 20    South Africa  105.8  107.9  110.0  112.2  114.4  116.7  119.0  121.4
# 21        Thailand   98.2  100.1  102.0  104.0  106.0  108.1  110.2  112.4
# 22           Egypt   92.5   94.3   96.1   98.0   99.9  101.9  103.9  106.0
# 23         Vietnam   85.7   87.4   89.2   91.0   92.9   94.8   96.8   98.8
# 24       Argentina   79.3   80.9   82.5   84.2   85.9   87.7   89.5   91.4
# 25        Pakistan   73.8   75.3   76.9   78.5   80.2   81.9   83.7   85.5
# 26        Malaysia   68.5   70.0   71.5   73.1   74.7   76.4   78.1   79.9
# 27     Netherlands   64.2   65.6   67.0   68.5   70.0   71.6   73.2   74.9
# 28         Ukraine   60.8   62.1   63.5   64.9   66.4   67.9   69.5   71.1
# 29         Belgium   57.3   58.6   59.9   61.3   62.7   64.1   65.6   67.1
#
#      2009  ...   2012   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0   565.7  ...  480.6  475.8  470.2  465.5  460.8  455.3  450.7  445.2  440.5
# 1   495.6  ...  570.5  600.3  632.8  668.5  707.2  749.3  795.1  844.6  897.8
# 2   507.6  ...  445.0  447.5  450.2  452.8  455.5  458.3  461.2  464.1  467.1
# 3   328.4  ...  349.8  357.4  365.2  373.3  381.6  390.2  399.1  408.3  417.8
# 4   371.0  ...  380.0  383.2  386.5  389.9  393.4  397.0  400.7  404.5  408.4
# 5   329.8  ...  338.0  340.8  343.7  346.6  349.6  352.6  355.7  358.8  362.0
# 6   305.6  ...  311.8  313.9  316.1  318.3  320.5  322.8  325.1  327.4  329.8
# 7   283.8  ...  299.7  305.2  310.8  316.5  322.3  328.2  334.2  340.3  346.5
# 8   280.6  ...  286.9  289.1  291.3  293.5  295.8  298.1  300.4  302.8  305.2
# 9   243.2  ...  254.6  258.5  262.5  266.6  270.7  274.9  279.2  283.5  287.9
# 10  230.8  ...  244.6  249.4  254.3  259.3  264.4  269.6  274.9  280.3  285.8
# 11  215.4  ...  228.0  232.4  236.9  241.5  246.2  251.0  255.9  260.9  266.0
# 12  201.0  ...  211.8  215.5  219.3  223.2  227.2  231.3  235.5  239.7  244.0
# 13  191.7  ...  201.5  204.9  208.4  212.0  215.6  219.3  223.1  227.0  230.9
# 14  174.9  ...  183.1  185.9  188.8  191.7  194.7  197.7  200.8  203.9  207.1
# 15  160.7  ...  168.3  170.9  173.6  176.3  179.1  181.9  184.8  187.7  190.7
# 16  155.3  ...  162.4  164.9  167.4  170.0  172.6  175.3  178.0  180.8  183.6
# 17  146.5  ...  155.5  158.6  161.8  165.1  168.4  171.8  175.3  178.9  182.5
# 18  137.0  ...  144.7  147.4  150.2  153.0  155.9  158.8  161.8  164.9  168.0
# 19  129.1  ...  136.2  138.7  141.2  143.8  146.4  149.1  151.8  154.6  157.4
# 20  123.8  ...  131.5  134.2  136.9  139.7  142.5  145.4  148.4  151.4  154.5
# 21  114.6  ...  121.6  124.0  126.5  129.1  131.7  134.4  137.1  139.9  142.7
# 22  108.1  ...  114.8  117.1  119.5  122.0  124.5  127.1  129.7  132.4  135.1
# 23  100.9  ...  107.4  109.7  112.0  114.4  116.8  119.3  121.9  124.5  127.2
# 24   93.3  ...   99.4  101.5  103.7  105.9  108.2  110.5  112.9  115.3  117.8
# 25   87.4  ...   93.3   95.4   97.5   99.7  101.9  104.2  106.5  108.9  111.4
# 26   81.7  ...   87.5   89.5   91.6   93.7   95.9   98.1  100.4  102.7  105.1
# 27   76.6  ...   81.9   83.8   85.7   87.7   89.7   91.8   93.9   96.1   98.3
# 28   72.8  ...   78.0   79.8   81.7   83.6   85.6   87.6   89.7   91.8   94.0
# 29   68.7  ...   73.6   75.3   77.1   78.9   80.8   82.7   84.6   86.6   88.7
#
#      2021
# 0   435.8
# 1   955.3
# 2   470.2
# 3   427.6
# 4   412.4
# 5   365.2
# 6   332.2
# 7   352.8
# 8   307.6
# 9   292.4
# 10  291.4
# 11  271.2
# 12  248.4
# 13  234.9
# 14  210.3
# 15  193.7
# 16  186.5
# 17  186.2
# 18  171.2
# 19  160.3
# 20  157.6
# 21  145.6
# 22  137.9
# 23  129.9
# 24  120.4
# 25  113.9
# 26  107.5
# 27  100.6
# 28   96.2
# 29   90.8
#
# [30 rows x 22 columns]

# %%
# 풀이1-1
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bae-v3/main/part4/ch11/greenhouse_gas.csv')

# 1) 연도 컬럼만 선택
cols = df.columns[1:]  # Country를 제외한 나머지

# 2) 각 연도별 최댓값의 행 번호 찾기
max_index = df[cols].idxmax()

# 3) 해당 행의 국가명 가져오기
df2 = df.loc[max_index]

# 4) 국가별 1위 횟수 세기
print(df2['Country'].value_counts())

# 정답: 11
# Out:
# Country
# China     11
# Brazil    10
# Name: count, dtype: int64

# %%
# 풀이1-2
# 1) CAGR 계산
df['CAGR'] = (df['2021'] / df['2001']) ** (1/20) - 1

# 2) 최댓값 구하기
result = df['CAGR'].max()
print(round(result, 3))
# 정답: 0.047
# Out:
# 0.047

# %% [markdown]
# ### 문제2

# %%
df.isnull().sum().idxmax()
df['S2_Temp'] = df['S2_Temp'].fillna(df['S2_Temp'].median())
print(round(df['S2_Temp'].mean(),3))
# Out:
# 25.055

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bae-v3/main/part4/ch11/sensor_data.csv')
df
# Out:
#                 DateTime  S1_Temp  S2_Temp  S3_Temp  S1_Humidity  S2_Humidity  \
# 0    2024-01-01 00:00:00     26.7     23.5     24.7         63.5         72.1
# 1    2024-01-01 01:00:00     27.0      NaN     23.4         63.9         50.5
# 2    2024-01-01 02:00:00     25.6     27.5     26.2         68.5         53.1
# 3    2024-01-01 03:00:00     24.7     24.3     26.0         56.1         66.9
# 4    2024-01-01 04:00:00     22.6     25.7     23.0         63.2         59.2
# ..                   ...      ...      ...      ...          ...          ...
# 495  2024-01-21 15:00:00     25.6     23.2     23.5         56.4         52.6
# 496  2024-01-21 16:00:00     27.0     24.9      NaN         61.8         52.5
# 497  2024-01-21 17:00:00     27.3      NaN     26.2         58.2         54.5
# 498  2024-01-21 18:00:00     26.8     24.0     26.6         65.9         64.0
# 499  2024-01-21 19:00:00     24.2     26.5      NaN         65.0         68.7
#
#      Illuminance  Noise    CO2  Pressure
# 0          320.8   47.3    NaN    1008.2
# 1          251.0   48.9  904.0    1008.1
# 2            NaN   57.5  752.7    1017.5
# 3          329.5   55.0  873.7    1005.6
# 4          312.4   34.5  959.0    1003.8
# ..           ...    ...    ...       ...
# 495        309.6   34.1  766.2    1016.6
# 496        272.9   31.3  787.7    1004.9
# 497        293.9   58.3  896.4    1010.2
# 498        284.0   44.5  705.3    1009.6
# 499        366.2   52.8  798.6    1009.9
#
# [500 rows x 10 columns]

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bae-v3/main/part4/ch11/sensor_data.csv')

# 1) 각 컬럼의 결측치 개수 확인
print(df.isnull().sum())

# 2) 결측치가 가장 많은 컬럼 찾기
col = df.isnull().sum().idxmax()
# print(col) #S2_Temp

# 3) 해당 컬럼의 중앙값 계산
m = df[col].median()
# print(m) #25.0

# 4) 결측치를 중앙값으로 대체
df[col] = df[col].fillna(m)

# 5) 평균 계산 (소수점 셋째 자리)
print(round(df[col].mean(), 3))
# Out:
# DateTime         0
# S1_Temp         50
# S2_Temp        150
# S3_Temp         80
# S1_Humidity      0
# S2_Humidity      0
# Illuminance     30
# Noise            0
# CO2             20
# Pressure         0
# dtype: int64
# 25.055

# %% [markdown]
# ### 문제3

# %%
# 3-1.
idx = df[df['cancel_TF'] == True]['order_amt'].abs().idxmax()
df.loc[idx, 'order_no']

# 3-2.
df.groupby(by ='cus_id')['order_amt'].sum().max()
# Out:
# 2877.21

# %%
df['order_amt'] =  df['quantity']* df['price']
df['cancel_TF'] = df['order_no'].str[0:1] == 'C'

df.loc[df['cancel_TF'] == True, 'order_amt' ] =df.loc[df['cancel_TF'] == True, 'order_amt' ] * (-1)

# %%
df[df['cancel_TF'] == True]
# Out:
#     order_no   cus_id   product  quantity  price  order_amt  cancel_TF
# 1    C536505  CUS0058   Headset         2  52.11     104.22       True
# 17   C536043  CUS0077   Headset         1  48.10      48.10       True
# 33   C536159  CUS0029   Monitor         2  53.33     106.66       True
# 45   C536883  CUS0037     Mouse         1  22.70      22.70       True
# 48   C536881  CUS0093  Keyboard         2  54.25     108.50       True
# ..       ...      ...       ...       ...    ...        ...        ...
# 902  C536775  CUS0017     Mouse         1  17.46      17.46       True
# 907  C536321  CUS0043  Keyboard         1  45.53      45.53       True
# 919  C536268  CUS0004    Laptop         1  23.20      23.20       True
# 938  C536003  CUS0018    Laptop         1  79.54      79.54       True
# 953  C536467  CUS0002   Monitor         1  33.90      33.90       True
#
# [102 rows x 7 columns]

# %%
df['order_amt'] =  df['quantity']* df['price']
df['cancel_TF'] = df['order_no'].str[0:1] == 'C'
df
# Out:
#     order_no   cus_id   product  quantity   price  order_amt  cancel_TF
# 0     536342  CUS0084   Monitor         2  110.02     220.04      False
# 1    C536505  CUS0058   Headset         2   52.11     104.22       True
# 2     536522  CUS0027   Headset         3   93.67     281.01      False
# 3     536544  CUS0077   Headset         3   74.05     222.15      False
# 4     536682  CUS0089   Headset         2  115.39     230.78      False
# ..       ...      ...       ...       ...     ...        ...        ...
# 951   536106  CUS0099    Laptop         2  107.95     215.90      False
# 952   536270  CUS0092   Headset         1   65.74      65.74      False
# 953  C536467  CUS0002   Monitor         1   33.90      33.90       True
# 954   536435  CUS0051    Laptop         1   15.22      15.22      False
# 955   536102  CUS0051  Keyboard         2   73.58     147.16      False
#
# [956 rows x 7 columns]

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bae-v3/main/part4/ch11/order_data.csv')
df
# Out:
#     order_no   cus_id   product  quantity   price
# 0     536342  CUS0084   Monitor         2  110.02
# 1    C536505  CUS0058   Headset         2   52.11
# 2     536522  CUS0027   Headset         3   93.67
# 3     536544  CUS0077   Headset         3   74.05
# 4     536682  CUS0089   Headset         2  115.39
# ..       ...      ...       ...       ...     ...
# 951   536106  CUS0099    Laptop         2  107.95
# 952   536270  CUS0092   Headset         1   65.74
# 953  C536467  CUS0002   Monitor         1   33.90
# 954   536435  CUS0051    Laptop         1   15.22
# 955   536102  CUS0051  Keyboard         2   73.58
#
# [956 rows x 5 columns]

# %%
# 전처리 수행
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bae-v3/main/part4/ch11/order_data.csv')

# 1) order_amt 생성
df['order_amt'] = df['quantity'] * df['price']

# 2) cancel_TF 생성
df['is_cancel'] = df['order_no'].str.contains('C')     # True/False 반환 - 방법1
#df['is_cancel'] = df['order_no'].str.startswith('C')  # True/False 반환 - 방법2

# 3) 취소 주문을 음수로 변환
cond = df['is_cancel'] == True
df.loc[cond, 'order_amt'] = df.loc[cond, 'order_amt'] * -1
df.head()
# Out:
#   order_no   cus_id  product  quantity   price  order_amt  is_cancel
# 0   536342  CUS0084  Monitor         2  110.02     220.04      False
# 1  C536505  CUS0058  Headset         2   52.11    -104.22       True
# 2   536522  CUS0027  Headset         3   93.67     281.01      False
# 3   536544  CUS0077  Headset         3   74.05     222.15      False
# 4   536682  CUS0089  Headset         2  115.39     230.78      False

# %%
# 문제 3-1
# 1. 취소 주문만 필터링
cond = df['is_cancel'] == True
cancel_df = df[cond]

# 2. order_amt 절댓값이 가장 큰 행의 인덱스
im = cancel_df['order_amt'].abs().idxmax()

# 3. 특정 인덱스의 전체 행 출력 (모든 컬럼)
print(cancel_df.loc[im])
# 정답: C542426
# Out:
# order_no     C542426
# cus_id       CUS0099
# product       Laptop
# quantity           6
# price         489.99
# order_amt   -2939.94
# is_cancel       True
# Name: 185, dtype: object

# %%
# 문제 3-2
# 1. 고객별 order_amt 합계 계산
df = df.groupby('cus_id')['order_amt'].sum()

# 2. 합계 중 최댓값
ma = df.max()

# 3. 소수점 둘째 자리까지 출력
print(round(ma, 2))
# 정답: 2877.21
# Out:
# 2877.21
